# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')
train.head(100)
# Out:
#     id                 time   feature_1     feature_2
# 0    0  2019-03-19 00:00:00  735.740043  54479.540513
# 1    1  2019-03-19 00:00:10  734.102947  47888.033714
# 2    2  2019-03-19 00:00:20  730.060336  47700.882325
# 3    3  2019-03-19 00:00:30  725.609742  47790.094648
# 4    4  2019-03-19 00:00:40  724.328480  47808.402381
# 5    5  2019-03-19 00:00:50  723.715893  47810.517411
# 6    6  2019-03-19 00:01:00  720.406875  47835.758121
# 7    7  2019-03-19 00:01:10  712.682269  47806.938481
# 8    8  2019-03-19 00:01:20  711.509741  47812.099044
# 9    9  2019-03-19 00:01:30  707.025594  47821.540514
# 10  10  2019-03-19 00:01:40  704.967640  47873.855627
# 11  11  2019-03-19 00:01:50  698.347054  47904.917155
# 12  12  2019-03-19 00:02:00  695.326174  48024.051144
# 13  13  2019-03-19 00:02:10  694.960018  48164.809903
# 14  14  2019-03-19 00:02:20  693.194633  48324.150384
# 15  15  2019-03-19 00:02:30  688.441547  48338.749346
# ...

# %%
x = train.iloc[:,2:3].values
y = train.iloc[:,3]
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.30)
print(x[:10])
print('\n')
print(y[:10])

lm = LinearRegression()

train_fit = lm.fit(x_train,y_train)

train_pred = lm.predict(x_test)
# Out:
# [[735.74004254]
#  [734.10294689]
#  [730.06033641]
#  [725.6097418 ]
#  [724.32848044]
#  [723.71589254]
#  [720.40687533]
#  [712.68226856]
#  [711.50974112]
#  [707.02559391]]
#
#
# 0    54479.540513
# 1    47888.033714
# 2    47700.882325
# 3    47790.094648
# 4    47808.402381
# 5    47810.517411
# 6    47835.758121
# 7    47806.938481
# 8    47812.099044
# 9    47821.540514
# Name: feature_2, dtype: float64

# %%
plt.scatter(x_train, y_train)
plt.plot(x_train, lm.predict(x_train), color='black')

# %%
plt.scatter(x_test, y_test, color='r')
plt.plot(x_test, train_pred, color='b')

# %%
#predicting the feature of test.csv
z = test.iloc[:,2:3].values
test_pred = lm.predict(z)
print(z)
print(test_pred)
label = test['id']
print(label)
# Out:
# [[423.06400408]
#  [423.34274896]
#  [423.1811861 ]
#  [421.27524276]
#  [422.2084443 ]
#  [422.61625443]
#  [425.82976622]
#  [426.24382984]
#  [426.04262137]
#  [424.73311578]
#  [424.70965423]
#  [414.82534701]
#  [423.89297149]
#  [423.06633104]
#  [422.81460608]
#  [422.61651739]
#  [422.31950596]
#  [421.86000216]
#  [421.24810388]
#  [405.4667347 ]
#  [419.74500659]
#  [420.74305753]
#  [420.50478579]
#  [419.48042336]
#  [419.1424361 ]
#  [418.72527568]
#  [418.21870657]
#  [417.86580704]
#  [417.33065821]
#  [417.38613952]
#  [416.80208388]
#  [417.10370948]
#  [416.838356  ]
#  [415.43180691]
#  [415.99109488]
#  [416.58340111]
#  [414.91786592]
#  [414.46304534]
#  [413.60274096]
#  [413.96148246]
#  [413.82694833]
#  [413.51477658]
#  [413.45592095]
#  [414.29598932]
#  [412.11021914]
#  [411.84440295]
#  [412.31246674]
#  [411.37179461]
#  [411.8920317 ]
#  [411.49366346]
#  [410.77503684]
#  [410.26853965]
#  [410.7175223 ]
#  [410.75293412]
#  [402.70025913]
# ...

# %%
df = pd.DataFrame(label)
df1 = pd.DataFrame(test_pred)

# %%
df.to_csv(r'C:\Users\dell\id.csv',index = False)

# %%
label = test['id']

# %%
print(label)
# Out:
# 0      564
# 1      565
# 2      566
# 3      567
# 4      568
# 5      569
# 6      570
# 7      571
# 8      572
# 9      573
# 10     574
# 11     575
# 12     576
# 13     577
# 14     578
# 15     579
# 16     580
# 17     581
# 18     582
# 19     583
# 20     584
# 21     585
# 22     586
# 23     587
# 24     588
# 25     589
# 26     590
# 27     591
# 28     592
# 29     593
#       ...
# 345    909
# 346    910
# 347    911
# 348    912
# 349    913
# 350    914
# 351    915
# 352    916
# 353    917
# 354    918
# 355    919
# 356    920
# 357    921
# 358    922
# 359    923
# 360    924
# 361    925
# 362    926
# 363    927
# 364    928
# 365    929
# 366    930
# 367    931
# 368    932
# 369    933
# 370    934
# 371    935
# 372    936
# 373    937
# 374    938
# Name: id, Length: 375, dtype: int64

# %%
df = pd.DataFrame(label)
df1 = pd.DataFrame(test_pred)

# %%
df.to_csv(r'C:\Users\dell\id.csv',index = False)
df1.to_csv(r'C:\Users\dell\feature2.csv',index = False)
